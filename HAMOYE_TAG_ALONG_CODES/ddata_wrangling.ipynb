# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fuel_data = pd.read_csv('climate_change.csv')
fuel_data.to_csv('climate_change.csv')

# %%
fuel_data.describe(include='all')
# Out:
#           Unnamed: 0  Unnamed: 0.1              record_id  utility_id_ferc1  \
# count   29523.000000  29523.000000                  29523      29523.000000
# unique           NaN           NaN                  29523               NaN
# top              NaN           NaN  f1_fuel_1994_12_1_0_7               NaN
# freq             NaN           NaN                      1               NaN
# mean    14761.000000  14761.000000                    NaN        118.601836
# std      8522.700335   8522.700335                    NaN         74.178353
# min         0.000000      0.000000                    NaN          1.000000
# 25%      7380.500000   7380.500000                    NaN         55.000000
# 50%     14761.000000  14761.000000                    NaN        122.000000
# 75%     22141.500000  22141.500000                    NaN        176.000000
# max     29522.000000  29522.000000                    NaN        514.000000
#
# ...

# %%
fuel_data.isnull().sum()
# Out:
# Unnamed: 0                        0
# Unnamed: 0.1                      0
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
#counting the unique values in the fuel unit column
fuel_data.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
fuel_data[['fuel_unit']].fillna(value ='mcf')
# Out:
#       fuel_unit
# 0           ton
# 1           ton
# 2           ton
# 3           ton
# 4           mcf
# ...         ...
# 29518       mcf
# 29519       mcf
# 29520       mcf
# 29521       ton
# 29522       mcf
#
# [29523 rows x 1 columns]

# %%
fuel_data.isnull().sum()
# Out:
# Unnamed: 0                        0
# Unnamed: 0.1                      0
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
#grouping by report
fuel_data.groupby('report_year')['report_year'].count
fuel_data[['report_year']]=
# Out:
#   File "C:\Users\Ann\AppData\Local\Temp/ipykernel_11384/1313607088.py", line 3
#     fuel_data[['report_year']]=
#                                ^
# SyntaxError: invalid syntax

# %%
# group and print first entries of all the group formed
#fuel_data.groupby('fuel_type_code_pud1').first()

# %%
fuel_df1 = fuel_data.iloc[0:19000].reset_index(drop=True)

# %%
fuel_df2=fuel_data.iloc[19000:].reset_index(drop=True)

# %%
# checking the length of the datafrme are equal
assert len(fuel_data) == (len(fuel_df1) + len(fuel_df2))

# %%
#merging df
pd.merge(fuel_df1, fuel_df2, how = "inner")

# %%
pd.merge(fuel_df1,fuel_df2, how = "outer")

# %%
pd.merge(fuel_df1 , fuel_df2, how = "left")
# Out:
#        Unnamed: 0                 record_id  utility_id_ferc1  report_year  \
# 0               0     f1_fuel_1994_12_1_0_7                 1         1994
# 1               1    f1_fuel_1994_12_1_0_10                 1         1994
# 2               2     f1_fuel_1994_12_2_0_1                 2         1994
# 3               3     f1_fuel_1994_12_2_0_7                 2         1994
# 4               4    f1_fuel_1994_12_2_0_10                 2         1994
# ...           ...                       ...               ...          ...
# 18995       18995   f1_fuel_2009_12_182_1_9               182         2009
# 18996       18996  f1_fuel_2009_12_182_1_10               182         2009
# 18997       18997  f1_fuel_2009_12_182_1_13               182         2009
# 18998       18998  f1_fuel_2009_12_182_1_14               182         2009
# 18999       18999    f1_fuel_2009_12_79_0_1                79         2009
#
# ...

# %%
#pd.concat([fuel_data, data_to_concat]).reset_index(drop=True)

# %%
fuel_data.duplicated().any()
# Out:
# False

# %%
#VISUALIZATION

# %%
# plt.figure(figsize =(7,4))
# plt.xticks(rotation = 90)
# fuel_unit =pd.DataFrame({'unit':['BBL','GAL','GRAMSU','KGU','MCF', 'MMBTU',"MWOTH",'TON'],
#                         'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
# sns.barplot(data = 'fuel_unit', x='unit', y='count')
# plt.xlabel('fuel unit')

# %%
# g =sns.barplot(data = 'fuel_unit', x='unit', y='count')
# g.set_yscale('log')
# g.set_ylim(1, 12000)
# plt.xlabel('fuel unit')
